# %%
import pandas as pd

# %%
df = pd.read_csv('Downloads/Restaurant reviews.csv')

# %%
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...                                                 ...    ...
# 9995  Madhumathi Mahajan Well to start with nice cou...      3
# 9996  This place has never disappointed us.. The foo...    4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...    1.5
# 9998  I personally love and prefer Chinese Food. Had...      4
# 9999  Checked in here to try some delicious chinese ...    3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [10000 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Restaurant', 'Reviewer', 'Review', 'Rating', 'Metadata', 'Time',
#        'Pictures', '7514'],
#       dtype='object')

# %%
df.drop(['Reviewer','Metadata', 'Time',
       'Pictures', '7514'], axis = 1, inplace = True)

# %%
df
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#      Rating
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# ...     ...
# 9995      3
# 9996    4.5
# 9997    1.5
# 9998      4
# 9999    3.5
#
# [10000 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# Restaurant     0
# Review        45
# Rating        38
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#      Rating
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# ...     ...
# 9995      3
# 9996    4.5
# 9997    1.5
# 9998      4
# 9999    3.5
#
# [9955 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# Restaurant    0
# Review        0
# Rating        0
# dtype: int64

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /home/admin1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/admin1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/admin1/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sw = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pre_pro(text):
    text = text.lower()
    text = text.translate(str.maketrans('','',string.punctuation))
    tokens = word_tokenize(text)
    tokens = [stemmer.stem(word) for word in tokens if word not in sw]
    return ' '.join(tokens)

# %%
df['Clean'] = df['Review'].apply(pre_pro)

# %%
df
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#      Rating                                              Clean
# 0         5  ambienc good food quit good saturday lunch cos...
# 1         5  ambienc good pleasant even servic prompt food ...
# 2         5  must tri great food great ambienc thnx servic ...
# 3         5  soumen da arun great guy behavior sincereti go...
# 4         5  food goodw order kodi drumstick basket mutton ...
# ...     ...                                                ...
# 9995      3  madhumathi mahajan well start nice courteou se...
# 9996    4.5  place never disappoint us food courteou staff ...
# 9997    1.5  bad rate mainli chicken bone found veg food ac...
# 9998      4  person love prefer chines food coupl time husb...
# 9999    3.5  check tri delici chines food seen nonveg lunch...
#
# [9955 rows x 4 columns]

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 5       3826
# 4       2373
# 1       1735
# 3       1192
# 2        684
# 4.5       69
# 3.5       47
# 2.5       19
# 1.5        9
# Like       1
# Name: count, dtype: int64

# %%
df[df['Rating']=='Like'].index
# Out:
# Index([7601], dtype='int64')

# %%
df.drop(index=df[df['Rating']=='Like'].index,inplace=True)

# %%
df['Rating'] = df['Rating'].apply(float)

# %%
df['Target'] =  df['Rating'].apply(lambda x :  0 if x>3.0 else 1)

# %%
df
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#       Rating                                              Clean  Target
# 0        5.0  ambienc good food quit good saturday lunch cos...       0
# 1        5.0  ambienc good pleasant even servic prompt food ...       0
# 2        5.0  must tri great food great ambienc thnx servic ...       0
# 3        5.0  soumen da arun great guy behavior sincereti go...       0
# 4        5.0  food goodw order kodi drumstick basket mutton ...       0
# ...      ...                                                ...     ...
# 9995     3.0  madhumathi mahajan well start nice courteou se...       1
# 9996     4.5  place never disappoint us food courteou staff ...       0
# 9997     1.5  bad rate mainli chicken bone found veg food ac...       1
# 9998     4.0  person love prefer chines food coupl time husb...       0
# 9999     3.5  check tri delici chines food seen nonveg lunch...       0
#
# [9954 rows x 5 columns]

# %%
df['Target'].value_counts()
# Out:
# Target
# 0    6315
# 1    3639
# Name: count, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x = df['Restaurant'].astype(str) + ' ' + df['Clean'].astype(str)

# %%
y = df['Target']

# %%
tf_vec = TfidfVectorizer(max_features=1000)
x_tfidf = tf_vec.fit_transform(x)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_tfidf,y,test_size= 0.2,random_state=42)

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
ypred = lr.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
acc= accuracy_score(ytest,ypred)
acc
# Out:
# 0.8663987945755901

# %%
svm = SVC(kernel='rbf')

# %%
svm.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
ypred1 = svm.predict(xtest)

# %%
acc1= accuracy_score(ytest,ypred1)
acc1
# Out:
# 0.8679055750878956

# %%
gnb = GaussianNB()

# %%
gnb.fit(xtrain.toarray(),ytrain)
# Out:
# GaussianNB()

# %%
ypred2 = gnb.predict(xtest.toarray())

# %%
acc2= accuracy_score(ytest,ypred2)
acc2
# Out:
# 0.796082370668006

# %%
import matplotlib.pyplot as plt

models = ['Logistic Regression', 'SVM', 'Naive Bayes']
accuracies = [0.8653, 0.8699, 0.7960]  

plt.figure(figsize=(7,5))
bars = plt.bar(models, accuracies, color=['steelblue', 'orange', 'green'])

plt.ylim(0, 1)
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')

for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2,
             bar.get_height(),
             f"{bar.get_height():.2f}",
             ha='center', va='bottom')

plt.show()
